# %%
# %matplotlib inline 
import numpy as np
import matplotlib.pyplot as plt
from math import exp, sqrt, pi

# %%
domaine = range(-100,100)
mu = 0 
sigma = 20

f = lambda x : 1/(sqrt(2*pi*pow(sigma,2))) * exp(-pow((x-mu),2)/(2*pow(sigma,2)))

y = [f(x) for x in domaine]
plot = plt.plot(domaine, y)

# %%
vector_aleatoire = np.random.rand(30)

# %%
plt.scatter(range(30), vector_aleatoire)

# %%
matrice_aleatoire = np.random.rand(3,5)

# %%
matrice_aleatoire
# Out:
# array([[0.52353383, 0.6516506 , 0.59094432, 0.55810915, 0.56276784],
#        [0.00170096, 0.56158096, 0.70153023, 0.51275785, 0.84244481],
#        [0.4553564 , 0.38894272, 0.58251739, 0.54662543, 0.99012486]])

# %%
matrice = np.random.rand(100,200)

# %%
np.sum(matrice)
# Out:
# 10083.050096474772

# %%
somme = np.sum(matrice,0) # somme de toutes les lignes pour toutes les colonnes

# %%
somme.shape
# Out:
# (200,)

# %%
plt.scatter(range(200), somme)

# %%
# tendance autour de la variable 50

# %%
plt.hist(somme)
# Out:
# (array([ 2.,  4., 16., 24., 43., 46., 29., 22.,  9.,  5.]),
#  array([42.31592598, 43.8584543 , 45.40098262, 46.94351094, 48.48603926,
#         50.02856758, 51.5710959 , 53.11362422, 54.65615254, 56.19868086,
#         57.74120918]),
#  <a list of 10 Patch objects>)

# %%
matrice = np.random.rand(1000,10000)

# %%
somme = np.sum(matrice,0)

# %%
somme.shape
# Out:
# (10000,)

# %%
plot = plt.hist(somme,bins=100)

# %%
print("La moyenne empirique de notre distribution est {}."
      .format(np.mean(somme)))
print("La moyenne empirique de la variable généré par la fonction rand est {}."
      .format(np.mean(np.random.rand(100000))))
print("La variance empirique de notre distribution est {}."
      .format(np.var(somme)))
print("La variance empirique de la variable généré par la fonction rand est {}."
      .format(np.var(np.random.rand(100000))))
# Out:
# La moyenne empirique de notre distribution est 499.83564321728574.
# La moyenne empirique de la variable généré par la fonction rand est 0.498854461902882.
# La variance empirique de notre distribution est 83.18823024097891.
# La variance empirique de la variable généré par la fonction rand est 0.0833705555939721.
